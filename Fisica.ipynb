# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 

tabela = pd.read_excel('trabalhofisicaexcel.xlsx',)
display(tabela)
# Out:
#    Delta D  Delta T
# 0   239.20     4.28
# 1   241.30     4.38
# 2   242.00     4.26
# 3   242.40     4.18
# 4   241.00     4.24
# 5   241.00     4.24
# 6   240.07     4.07

# %%
sns.pairplot(tabela)
plt.show()
g = sns.relplot(x="Delta T", y="Delta D",kind = 'line', data=tabela)
g.fig.autofmt_xdate()
g.regression()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-b76f3cb6de52> in <module>
#       3 g = sns.relplot(x="Delta T", y="Delta D",kind = 'line', data=tabela)
#       4 g.fig.autofmt_xdate()
# ----> 5 g.regression()
#       6 plt.show()
#       7
#
# AttributeError: 'FacetGrid' object has no attribute 'regression'
